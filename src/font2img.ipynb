# %%
# %run font2img.py ../GoogleFonts/test_ttf ../Alphabet.txt ../GoogleFonts/test_font
# Out:
# FredokaOne-Regular.ttf        :   0%|          | 0/172 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# NotoSansTC[wght].ttf          :   1%|          | 1/172 [00:00<00:54,  3.16it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# NerkoOne-Regular.ttf          :   1%|          | 2/172 [00:01<01:40,  1.69it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# MuktaMalar-SemiBold.ttf       :   2%|▏         | 3/172 [00:01<01:18,  2.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Urbanist-Italic[wght].ttf     :   2%|▏         | 4/172 [00:01<01:11,  2.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# Exo[wght].ttf                 :   3%|▎         | 5/172 [00:02<01:07,  2.46it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# RedRose[wght].ttf             :   3%|▎         | 6/172 [00:02<01:05,  2.53it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
# GothicA1-Black.ttf            :   4%|▍         | 7/172 [00:02<01:04,  2.57it/s]
#
#
# ...
