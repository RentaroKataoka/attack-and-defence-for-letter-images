# %%
import japanize_matplotlib
import matplotlib.pyplot as plt
import os
from PIL import Image

# %%
dirname_org1 = "../org+adv/org/1/3.png"
dirname_adv1 = "../org+adv/adv/1/1→8/3.png"
dirname_grad1 = "../org+adv/grad/1/3.png"
dirname_org4 = "../org+adv/org/4/291.png"
dirname_adv4 = "../org+adv/adv/4/4→2/291.png"
dirname_grad4 = "../org+adv/grad/4/291.png"
dirname_org6 = "../org+adv/org/6/2.png"
dirname_adv6 = "../org+adv/adv/6/6→5/2.png"
dirname_grad6 = "../org+adv/grad/6/2.png"
dirname_org9 = "../org+adv/org/9/39.png"
dirname_adv9 = "../org+adv/adv/9/9→7/39.png"
dirname_grad9 = "../org+adv/grad/9/39.png"

# %%
cnt = 0
plt.figure(figsize=(8,10))
# for i in [dirname_org1, dirname_adv1, dirname_grad1, dirname_org4, dirname_adv4, dirname_grad4, dirname_org6, dirname_adv6, dirname_grad6, dirname_org9, dirname_adv9, dirname_grad9]:
for i in [dirname_org1, dirname_adv1, dirname_grad1, dirname_org4, dirname_adv4, dirname_grad4]:
    cnt += 1
    img = Image.open(i)
    plt.subplot(2, 3,cnt)
    # plt.subplots_adjust(wspace=0.1, hspace=0.1)
    plt.xticks([], [])
    plt.yticks([], [])
    if i == dirname_org1:
        plt.title("class1", color="black", y=-0.25, fontsize=32)
    elif i == dirname_adv1:
        plt.title("class8", color="black", y=-0.25, fontsize=32)
    elif i == dirname_grad1:
        plt.title("heatmap", color="black", y=-0.25, fontsize=32)
    elif i == dirname_org4:
        plt.title("class4", color="black", y=-0.25, fontsize=32)
    elif i == dirname_adv4:
        plt.title("class2", color="black", y=-0.25, fontsize=32)
    elif i == dirname_grad4:
        plt.title("heatmap", color="black", y=-0.25, fontsize=32)
    # elif i == dirname_org6:
    #     plt.title("class6", color="black", y=-0.13)
    # elif i == dirname_adv6:
    #     plt.title("class5", color="black", y=-0.13)
    # elif i == dirname_org9:
    #     plt.title("class4", color="black", y=-0.38, fontsize=20)
    # elif i == dirname_adv9:
    #     plt.title("class2", color="black", y=-0.38, fontsize=20)
    plt.imshow(img, cmap="gray")
    # plt.imshow(ex, cmap="gray")
# plt.tight_layout()
plt.subplots_adjust(wspace=0.1, hspace=-0.45)
plt.savefig("../org+adv/result.png", bbox_inches='tight', pad_inches=0.1)
plt.show()
